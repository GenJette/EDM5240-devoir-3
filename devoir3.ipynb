# %% [markdown]
# # Devoir 3 pour JHR

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %%
info = pd.read_csv("ati.csv")

# %%
info
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %%
info.columns
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %% [markdown]
# Maintenant, je veux savoir quel est le nombre de pages le plus élevé.

# %%
info.pages.max()
# Out:
# 2435124351

# %%
info.owner_org_title.value_counts()
# Out:
# National Defence | Défense nationale                                                                                                                             2605
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                1650
# Employment and Social Development Canada | Emploi et Développement social Canada                                                                                 1541
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       1323
# Health Canada | Santé Canada                                                                                                                                     1164
# ...

# %% [markdown]
# Ensuite, j'ai voulu savoir quelles étaient toutes les directions dans le .csv et combien de contrats étaient attribués à chacune d'entre elles.

# %%
pet = info.owner_org_title.str.contains("Fondation Pierre Elliott Trudeau")

# %%
info[pet]
# Out:
#        year  month request_number  \
# 22855  2015      5     A-2015-001
# 22856  2015      5     A-2015-002
# 22857  2015      5     A-2015-003
# 22858  2015      6     A-2015-004
# 22859  2016     12     A-2016-003
# 22860  2017      2     A-2016-001
# 22861  2017      2     A-2016-002
#
#                                               summary_en  \
# 22855  Provide a list of all donors to the Foundation...
# 22856  Provide a list of the amounts received by the ...
# 22857  Provide copies of all documents regarding the ...
# 22858  A list of all donors to the Pierre Elliott Tru...
# 22859  A list of all donors to the Foundation for the...
# 22860  All donors from 1 November 2015 to 29 November...
# 22861  Donors, including names, addresses and amounts...
#
#                                               summary_fr  \
# 22855  Fournir une liste de tous les donateurs à la F...
# 22856  Fournir une liste des sommes reçues par la Fon...
# ...

# %% [markdown]
# Après avoir vu qu'il y avait la Fondation Pierre Elliott Trudeau dans la liste que j'ai extraite, j'ai voulu savoir les types de contrats qui étaient associés à la fondation.

# %% [markdown]
# J'adore les notebooks!
